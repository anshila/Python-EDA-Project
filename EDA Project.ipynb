# %% [markdown]
# # <center><font color=brown>EXPLORATORY DATA ANALYSIS</font></center>

# %% [markdown]
# ##### Providing a dataset of employees working in ABC company. It consists of 458 rows and 9 columns. The company needs the detailed report and explanation of their employees in each team, also need to identify the following:

# %% [markdown]
# ***
# 1. [How many are there in each Team and the percentage splitting with respect to the total employees.](#question1)
# 2. [Segregate the employees w.r.t different positions.](#question2)
# 3. [Find from which age group most of the employees belong to.](#question3)
# 4. [Find out under which team and position, spending in terms of salary is high.](#question4)
# 5. [Find if there is any correlation between age and salary , represent it visually.](#question5)
# <br>Before doing the above questions,perform pre processing of the dataset. Also, the column height is having incorrect data, changing the data of that particular column with any random numbers between 150 and 180.
# ***

# %% [markdown]
# Presented here is a comprehensive dataset detailing the workforce of ABC Company, comprising 458 rows and 9 columns. Each row encapsulates vital information about an employee, including their name, team affiliation, position, age, height, weight, college background, and salary. The objective of this exploration is to deliver a detailed report and analysis of the employees within each team. By scrutinizing this dataset, we aim to uncover patterns in team compositions, positional distributions, and other noteworthy trends that can provide valuable insights for human resources, team management, and organizational decision-making. This Exploratory Data Analysis (EDA) endeavors to unravel the story embedded in the data and contribute to a more profound understanding of ABC Company's workforce dynamics.
# ***
# **Steps for Exploratory Data Analysis (EDA):**
# 1. [Importing Required Libraries](#step1)
# 2. [Reading Dataset](#step2)
# 3. [Analyzing the Data](#step3)
# 4. [Data Preprocessing](#step4)
# 5. [Exploratory Data Analysis (EDA) and Visualization](#step5)
# ***

# %% [markdown]
# #### <center><font color=green><a id="step1">Step 1: Importing Required Libraries</a></font></center>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# Import all of the libraries needed for our investigation, including those for data loading, statistical analysis, visualizations,

# %% [markdown]
# #### <center><font color=green><a id="step2">Step 2: Reading Dataset</a></font></center>

# %%
df=pd.read_excel('myexcel.xlsx')
df
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %% [markdown]
# Loading the data into the pandas data frame is certainly one of the most important steps in EDA.

# %% [markdown]
# #### <center><font color=green><a id="step3">Step 3: Analyzing the Data</a></font></center>

# %%
# To display the top 5 rows 
df.head()
# Out:
#             Name            Team  Number Position  Age               Height  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1    Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2   John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3    R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
#
#    Weight            College     Salary
# 0     180              Texas  7730337.0
# 1     235          Marquette  6796117.0
# 2     205  Boston University        NaN
# 3     185      Georgia State  1148640.0
# 4     231                NaN  5000000.0

# %%
# To display the bottom 5 rows 
df.tail()
# Out:
#              Name       Team  Number Position  Age               Height  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454     Raul Neto  Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455  Tibor Pleiss  Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456   Jeff Withey  Utah Jazz      24        C   26                  7-0
# 457      Priyanka  Utah Jazz      34        C   25  2023-03-07 00:00:00
#
#      Weight College     Salary
# 453     203  Butler  2433333.0
# 454     179     NaN   900000.0
# 455     256     NaN  2900000.0
# 456     231  Kansas   947276.0
# 457     231  Kansas   947276.0

# %%
# Display statistical summary of the dataframe
df.describe(include='all')
# Out:
#                  Name                  Team      Number Position         Age  \
# count             458                   458  458.000000      458  458.000000
# unique            458                    30         NaN        5         NaN
# top     Avery Bradley  New Orleans Pelicans         NaN       SG         NaN
# freq                1                    19         NaN      102         NaN
# mean              NaN                   NaN   17.713974      NaN   26.934498
# std               NaN                   NaN   15.966837      NaN    4.400128
# min               NaN                   NaN    0.000000      NaN   19.000000
# 25%               NaN                   NaN    5.000000      NaN   24.000000
# 50%               NaN                   NaN   13.000000      NaN   26.000000
# 75%               NaN                   NaN   25.000000      NaN   30.000000
# max               NaN                   NaN   99.000000      NaN   40.000000
#
# ...

# %% [markdown]
# Using describe function, we can see the number of null values, datatypes, and memory usage as shown in the above outputs along with descriptive statistics.

# %%
#Display concise summary of a DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %% [markdown]
# info() function will give us the basic information about the dataset.

# %%
#isnull() is widely been in all pre-processing steps to identify null values in the data
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
# Check if there are any duplicates in dataset
df.duplicated().sum()
# Out:
# 0

# %%
# View all column names of DataFrame
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
#Display unique values in the Team column of DataFrame
df.Team.unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz'],
#       dtype=object)

# %%
#View Count of Unique values in the 'Team' column of DataFrame
df.Team.nunique()
# Out:
# 30

# %%
#Display unique values in the Position column of DataFrame
df.Position.unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C'], dtype=object)

# %%
#View Count of Unique values in the Position column of DataFrame
df.Position.nunique()
# Out:
# 5

# %% [markdown]
# #### <center><font color=green><a id="step4">Step 4: Data Preprocessing</a></font></center>

# %%
# 'Height' coloumn data replaced with random values between 150 & 180
Height=np.random.randint(150,180,size=458)
df['Height']=Height
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     174     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     155     235
# 2     John Holland  Boston Celtics      30       SG   27     172     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     167     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     162     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     164     203
# 454      Raul Neto       Utah Jazz      25       PG   24     174     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     154     256
# 456    Jeff Withey       Utah Jazz      24        C   26     159     231
# 457       Priyanka       Utah Jazz      34        C   25     163     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# Handle missing data in 'College' column by replacing into 'Unknown' value
df['College'].fillna('Unknown', inplace=True)
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     174     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     155     235
# 2     John Holland  Boston Celtics      30       SG   27     172     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     167     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     162     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     164     203
# 454      Raul Neto       Utah Jazz      25       PG   24     174     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     154     256
# 456    Jeff Withey       Utah Jazz      24        C   26     159     231
# 457       Priyanka       Utah Jazz      34        C   25     163     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# #### <center><font color=green><a id="step5">Step5: Exploratory Data Analysis (EDA) and Visualization</a></font></center>

# %% [markdown]
# ####  <a id="question1">1. How many are there in each Team and the percentage splitting with respect to the total employees.</a>

# %%
# Number of employees in each team
team_count = df['Team'].value_counts()
team_count
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
# Percentage splitting of the total employees
percentage_splitting = round((team_count / len(df)) * 100,2)
percentage_splitting
# Out:
# Team
# New Orleans Pelicans      4.15
# Memphis Grizzlies         3.93
# Utah Jazz                 3.49
# New York Knicks           3.49
# Milwaukee Bucks           3.49
# Brooklyn Nets             3.28
# Portland Trail Blazers    3.28
# Oklahoma City Thunder     3.28
# Denver Nuggets            3.28
# Washington Wizards        3.28
# Miami Heat                3.28
# Charlotte Hornets         3.28
# Atlanta Hawks             3.28
# San Antonio Spurs         3.28
# Houston Rockets           3.28
# Boston Celtics            3.28
# Indiana Pacers            3.28
# Detroit Pistons           3.28
# Cleveland Cavaliers       3.28
# Chicago Bulls             3.28
# Sacramento Kings          3.28
# Phoenix Suns              3.28
# Los Angeles Lakers        3.28
# Los Angeles Clippers      3.28
# Golden State Warriors     3.28
# Toronto Raptors           3.28
# Philadelphia 76ers        3.28
# Dallas Mavericks          3.28
# Orlando Magic             3.06
# Minnesota Timberwolves    3.06
# ...

# %%
df['percentage_splitting'] = df['Team'].map(percentage_splitting)
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     174     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     155     235
# 2     John Holland  Boston Celtics      30       SG   27     172     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     167     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     162     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     164     203
# 454      Raul Neto       Utah Jazz      25       PG   24     174     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     154     256
# 456    Jeff Withey       Utah Jazz      24        C   26     159     231
# 457       Priyanka       Utah Jazz      34        C   25     163     231
#
#                College     Salary  percentage_splitting
# ...

# %%
# Create a new DataFrame with the results
team_percentage_splitting = pd.DataFrame({'Team': team_count.index, 'Number of Employees': team_count.values, 'Percentage Splitting': percentage_splitting.values})
team_percentage_splitting
# Out:
#                       Team  Number of Employees  Percentage Splitting
# 0     New Orleans Pelicans                   19                  4.15
# 1        Memphis Grizzlies                   18                  3.93
# 2                Utah Jazz                   16                  3.49
# 3          New York Knicks                   16                  3.49
# 4          Milwaukee Bucks                   16                  3.49
# 5            Brooklyn Nets                   15                  3.28
# 6   Portland Trail Blazers                   15                  3.28
# 7    Oklahoma City Thunder                   15                  3.28
# 8           Denver Nuggets                   15                  3.28
# 9       Washington Wizards                   15                  3.28
# 10              Miami Heat                   15                  3.28
# 11       Charlotte Hornets                   15                  3.28
# ...

# %% [markdown]
# The data reveals the distribution of employees across various teams, showcasing team sizes and their respective percentages of the total workforce. The 'New Orleans Pelicans' and 'Memphis Grizzlies' lead with 19 and 18 employees, respectively, while other teams maintain a relatively consistent workforce percentage, ranging from 3.06% to 4.15%.

# %%
# Plotting the bar chart 
plt.figure(figsize=(12,6))
plt.xticks(rotation="vertical")
plt.title('Percentage of Employees in Each Team')
plt.xlabel('Team')
plt.ylabel('Percentage')
sns.countplot(x='Team',data=df,hue='Team',palette='plasma')
plt.show()

# %% [markdown]
# ####  <a id="question2">2. Segregate the employees w.r.t different positions.</a>

# %%
# View the name & position from the dataset
df[['Name', 'Position']]
# Out:
#               Name Position
# 0    Avery Bradley       PG
# 1      Jae Crowder       SF
# 2     John Holland       SG
# 3      R.J. Hunter       SG
# 4    Jonas Jerebko       PF
# ..             ...      ...
# 453   Shelvin Mack       PG
# 454      Raul Neto       PG
# 455   Tibor Pleiss        C
# 456    Jeff Withey        C
# 457       Priyanka        C
#
# [458 rows x 2 columns]

# %%
df['Position'].value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
#Segregate employees by positions
position_count = df.groupby('Position').size().reset_index(name='No: of Employees')
position_count
# Out:
#   Position  No: of Employees
# 0        C                79
# 1       PF               100
# 2       PG                92
# 3       SF                85
# 4       SG               102

# %%
# plotting with seaborn
plt.figure(figsize=(10, 6))
sns.countplot(x='Position', data=df,hue='Position', palette='deep')
plt.title('Number of Employees in Each Position')
plt.xlabel('Position')
plt.ylabel('Number of Employees')
plt.show()

# %% [markdown]
# The distribution of employees across different positions in the dataset reveals varying representation, with the highest count in 'SG' at 102 employees, closely followed by 'PF' at 100 employees. 'PG' and 'C' have 92 and 79 employees, respectively, while 'SF' account for 85 employees. This insight into positional composition provides valuable information for team management.

# %% [markdown]
# #### <a id="question3">3. Find from which age group most of the employees belong to.</a>

# %%
df['Age']
# Out:
# 0      25
# 1      25
# 2      27
# 3      22
# 4      29
#        ..
# 453    26
# 454    24
# 455    26
# 456    26
# 457    25
# Name: Age, Length: 458, dtype: int64

# %%
df['Age'].value_counts()
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x='Age',data=df,hue='Age',palette='rocket')
plt.title('Age Distribution of Employees')
plt.xlabel('Age')
plt.ylabel('No: of Employees')
plt.show()

# %% [markdown]
# <b>The age distribution chart provides a visual representation of the workforce within the organization, showcasing the count of employees in each age group.</b><br><br>
# Notably, the highest concentration of employees falls within the 22 to 29 age range, indicating a substantial presence of early to mid-career professionals. <br>
# The distribution also reveals a noticeable representation of employees in their late 20s and early 30s, suggesting a cohort with a blend of experience and ambition.

# %%
#Age group 
bins = [15,20,25,30,35,40,45]
labels = ['15-20','21-25','26-30','31-35','36-40','41-45']
df['Age Group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)
df['Age Group'].value_counts()
# Out:
# Age Group
# 26-30    182
# 21-25    152
# 31-35     90
# 36-40     29
# 41-45      3
# 15-20      2
# Name: count, dtype: int64

# %%
# Plot age group distribution
plt.figure(figsize=(10, 6))
sns.countplot(x='Age Group', data=df, hue='Age Group',palette='rocket')
plt.title('Age Group Distribution of Employees')
plt.xlabel('Age Group')
plt.ylabel('Number of Employees')
plt.show()

# %% [markdown]
# The countplot function is employed to create a bar chart, with the x-axis representing the age groups and the y-axis indicating the number of employees. This visualization provides a clear and engaging representation of the age distribution within the workforce, facilitating easy interpretation and analysis of the data.
#
# The highest count is observed in the 26-30 age group, indicating a significant presence of employees in their mid-career stage. Following closely, the 21-25 and 31-35 age groups emerge as the second and third highest, respectively. The 36-40 and 41-45 age groups represent the next tiers in the workforce. This breakdown helps us understand the diverse mix of experiences and career stages within the organization.

# %% [markdown]
# #### <a id="question4">4. Find out under which team and position, spending in terms of salary is high.</a>

# %%
x = df['Salary'].mean()
df['Salary'].fillna(x,inplace = True)
df1=df[['Team','Position','Salary']]
df1
# Out:
#                Team Position        Salary
# 0    Boston Celtics       PG  7.730337e+06
# 1    Boston Celtics       SF  6.796117e+06
# 2    Boston Celtics       SG  4.833970e+06
# 3    Boston Celtics       SG  1.148640e+06
# 4    Boston Celtics       PF  5.000000e+06
# ..              ...      ...           ...
# 453       Utah Jazz       PG  2.433333e+06
# 454       Utah Jazz       PG  9.000000e+05
# 455       Utah Jazz        C  2.900000e+06
# 456       Utah Jazz        C  9.472760e+05
# 457       Utah Jazz        C  9.472760e+05
#
# [458 rows x 3 columns]

# %%
# Group by Team and Position, then sum the salaries
team_position_salary = df1.groupby(['Team', 'Position'])['Salary'].sum()
team_position_salary
# Out:
# Team                Position
# Atlanta Hawks       C           22756250.0
#                     PF          23952268.0
#                     PG           9763400.0
#                     SF           6000000.0
#                     SG          10431032.0
#                                    ...
# Washington Wizards  C           24490429.0
#                     PF          11300000.0
#                     PG          18022415.0
#                     SF          11158800.0
#                     SG          11356992.0
# Name: Salary, Length: 149, dtype: float64

# %%
# Find the team and position with the highest spending
highest_spending_position = team_position_salary.idxmax()
highest_salary = team_position_salary.loc[highest_spending_position]
team, position = highest_spending_position
team, position,highest_salary
# Out:
# ('Los Angeles Lakers', 'SF', 31866445.0)

# %%
# Plotting the bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x='Team', y='Salary', hue='Position', data=df1)
plt.title('Highest Spending Salary by Team and Position')
plt.xlabel('Team')
plt.ylabel('Total Salary')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The bar plot visualizes the highest spending salary by team and position. Each bar represents the total salary for a specific team, differentiated by positions. The highest spending position is highlighted for each team, providing a clear comparison of salary distribution.
# eam.

# %% [markdown]
# * **X-axis (Horizontal Axis):** The x-axis represents the "Team." Each bar on the plot corresponds to a specific team in the dataset. <br>
# * **Y-axis (Vertical Axis):** The y-axis represents the "Total Salary." The height of each bar corresponds to the total salary for a particular team and position combination. <br>
# * **Hue (Color):** The hue (color) represents the "Position." Different positions within each team are distinguished by different colors. This additional dimension helps in understanding how the total salary is distributed among various positions within each team.

# %% [markdown]
# #### <a id="question5">5. Find if there is any correlation between age and salary , represent it visually</a>

# %%
df2=df[['Age','Salary']]
df2
# Out:
#      Age        Salary
# 0     25  7.730337e+06
# 1     25  6.796117e+06
# 2     27  4.833970e+06
# 3     22  1.148640e+06
# 4     29  5.000000e+06
# ..   ...           ...
# 453   26  2.433333e+06
# 454   24  9.000000e+05
# 455   26  2.900000e+06
# 456   26  9.472760e+05
# 457   25  9.472760e+05
#
# [458 rows x 2 columns]

# %%
#Calculate the correlation matrix
correlation= df2.corr()
correlation
# Out:
#             Age   Salary
# Age     1.00000  0.21117
# Salary  0.21117  1.00000

# %%
sns.heatmap(correlation, annot=True, cmap="crest")
plt.title("Correlation Matrix between Age & Salary of Employee Dataset")
plt.show()

# %% [markdown]
# The correlation matrix for "Age" and "Salary" indicates a positive correlation. This value suggests a weak positive linear relationship between age and salary. While the correlation is statistically significant, the strength of the association is relatively low. Therefore, as age increases, there is a tendency for salary to also increase, but the effect is not particularly strong.
